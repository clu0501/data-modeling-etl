# %% [markdown]
# # Ingesting Movies Data Into Postgres

# %% [markdown]
# ## Installing Libraries

# %%
# !pip install psycopg2
# !pip install pandas
# Out:
# Requirement already satisfied: psycopg2 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (2.9.9)
# Requirement already satisfied: pandas in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import psycopg2
import pandas as pd

# %% [markdown]
# ## Connecting to Postgres

# %%
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=Christopher.J.Lu password=Housepen67!")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %% [markdown]
# Creating a cursor to execute our queries.

# %%
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

# %% [markdown]
# Setting session's autocommit to true so we don't have to manually call commit after every transaction.

# %%
conn.set_session(autocommit=True)

# %% [markdown]
# ## Creating a Database

# %%
try: 
    cur.execute("drop database movies if exists")
    cur.execute("create database movies")
except psycopg2.Error as e:
    print(e)
# Out:
# syntax error at or near "if"
# LINE 1: drop database movies if exists
#                              ^

# %% [markdown]
# ## Connecting to Database

# %% [markdown]
# ## Ingesting Data From Files

# %%
imdb_data = pd.read_csv('../data/imdb_top_1000.csv')
oscar_data = pd.read_csv('../data/the_oscar_award.csv')

# %% [markdown]
# ## Light Data Processing

# %% [markdown]
# Let's look at the data first:

# %%
imdb_data.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
# 6                                   Pulp Fiction          1994           A
# 7                               Schindler's List          1993           A
# 8                                      Inception          2010          UA
# 9                                     Fight Club          1999           A
#
#    Runtime                      Genre  IMDB_Rating  \
# 0  142 min                      Drama          9.3
# 1  175 min               Crime, Drama          9.2
# 2  152 min       Action, Crime, Drama          9.0
# 3  202 min               Crime, Drama          9.0
# 4   96 min               Crime, Drama          9.0
# 5  201 min   Action, Adventure, Drama          8.9
# 6  154 min               Crime, Drama          8.9
# 7  195 min  Biography, Drama, History          8.9
# 8  148 min  Action, Adventure, Sci-Fi          8.8
# 9  139 min                      Drama          8.8
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
# 5  Gandalf and Aragorn lead the World of Men agai...        94.0
# 6  The lives of two mob hitmen, a boxer, a gangst...        94.0
# 7  In German-occupied Poland during World War II,...        94.0
# 8  A thief who steals corporate secrets through t...        74.0
# 9  An insomniac office worker and a devil-may-car...        66.0
#
#                Director              Star1                 Star2  \
# 0        Frank Darabont        Tim Robbins        Morgan Freeman
# 1  Francis Ford Coppola      Marlon Brando             Al Pacino
# 2     Christopher Nolan     Christian Bale          Heath Ledger
# 3  Francis Ford Coppola          Al Pacino        Robert De Niro
# 4          Sidney Lumet        Henry Fonda           Lee J. Cobb
# 5         Peter Jackson        Elijah Wood       Viggo Mortensen
# 6     Quentin Tarantino      John Travolta           Uma Thurman
# 7      Steven Spielberg        Liam Neeson         Ralph Fiennes
# 8     Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt
# 9         David Fincher          Brad Pitt         Edward Norton
#
#                Star3             Star4  No_of_Votes        Gross
# 0         Bob Gunton    William Sadler      2343110   28,341,469
# 1         James Caan      Diane Keaton      1620367  134,966,411
# 2      Aaron Eckhart     Michael Caine      2303232  534,858,444
# 3      Robert Duvall      Diane Keaton      1129952   57,300,000
# 4      Martin Balsam      John Fiedler       689845    4,360,000
# 5       Ian McKellen     Orlando Bloom      1642758  377,845,905
# 6  Samuel L. Jackson      Bruce Willis      1826188  107,928,762
# 7       Ben Kingsley  Caroline Goodall      1213505   96,898,818
# 8        Elliot Page      Ken Watanabe      2067042  292,576,195
# 9          Meat Loaf      Zach Grenier      1854740   37,030,102

# %% [markdown]
# We can use the columns in this dataframe to create our Movies table (refer to the ER diagram in the README):
# - Movie_ID -> We'll just use the dataframe index here
# - Series_Title -> Rename to Movie_Title
# - Released_Year
# - Certificate
# - Runtime -> Rename to Runtime_Minutes
# - Genre
#
# We can also use these columns to create our Movie_Ratings table:
# - Movie_ID (We will join this to our Movies table using Movie Title to get the Movie_ID)
# - IMDB_Rating
# - Meta_score -> Rename to Metacritic_Score
# - No_of_Votes -> Rename to No_of_IMDB_Votes
#
# Finally, we can also get our Movie_Box_Office table:
# - Movie_ID (We will join this to our Movies table using Movie Title to get the Movie_ID)
# - Gross -> Rename to Gross_USD

# %% [markdown]
# Let's add our Movie_ID primary column to the base imdb_data set since we'll be using it in all our tables.

# %%
imdb_data.insert(0, 'Movie_ID', imdb_data.index + 1)
imdb_data.head()
# Out:
#    Movie_ID                                        Poster_Link  \
# 0         1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1         2  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2         3  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3         4  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4         5  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# Now, let's drop the columns we won't be needing.

# %%
to_drop = [
    'Poster_Link',
    'Overview',
    'Star1',
    'Star2',
    'Star3',
    'Star4',
]

imdb_data.drop(to_drop, inplace=True, axis=1)
imdb_data.head()
# Out:
#    Movie_ID              Series_Title Released_Year Certificate  Runtime  \
# 0         1  The Shawshank Redemption          1994           A  142 min
# 1         2             The Godfather          1972           A  175 min
# 2         3           The Dark Knight          2008          UA  152 min
# 3         4    The Godfather: Part II          1974           A  202 min
# 4         5              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#    No_of_Votes        Gross
# 0      2343110   28,341,469
# 1      1620367  134,966,411
# 2      2303232  534,858,444
# 3      1129952   57,300,000
# 4       689845    4,360,000

# %%
# Getting the columns we need
movies_raw = imdb_data[["Movie_ID", "Series_Title", "Released_Year", "Certificate", "Runtime", "Genre", "Director"]]
movies_raw.head()
# Out:
#    Movie_ID              Series_Title Released_Year Certificate  Runtime  \
# 0         1  The Shawshank Redemption          1994           A  142 min
# 1         2             The Godfather          1972           A  175 min
# 2         3           The Dark Knight          2008          UA  152 min
# 3         4    The Godfather: Part II          1974           A  202 min
# 4         5              12 Angry Men          1957           U   96 min
#
#                   Genre              Director
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet

# %%
# Renaming the columns
movies_temp = movies_raw
movies_temp.rename(columns={'Series_Title':'Movie_Title', 'Runtime':'Runtime_Minutes'}, inplace=True)
movies_temp.head()
# Out:
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/2227702340.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_temp.rename(columns={'Series_Title':'Movie_Title', 'Runtime':'Runtime_Minutes'}, inplace=True)
#    Movie_ID               Movie_Title Released_Year Certificate  \
# 0         1  The Shawshank Redemption          1994           A
# 1         2             The Godfather          1972           A
# 2         3           The Dark Knight          2008          UA
# 3         4    The Godfather: Part II          1974           A
# 4         5              12 Angry Men          1957           U
#
#   Runtime_Minutes                 Genre              Director
# 0         142 min                 Drama        Frank Darabont
# 1         175 min          Crime, Drama  Francis Ford Coppola
# 2         152 min  Action, Crime, Drama     Christopher Nolan
# 3         202 min          Crime, Drama  Francis Ford Coppola
# 4          96 min          Crime, Drama          Sidney Lumet

# %%
# We need to convert Runtime_Minutes into a integer field by removing the " min" from the data and 
# changing the data type of the column from varchar to integer.
movies_temp["Runtime_Minutes"] = pd.to_numeric(movies_temp["Runtime_Minutes"].replace(" min", "", regex=True))
# Out:
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/3606572449.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_temp["Runtime_Minutes"] = pd.to_numeric(movies_temp["Runtime_Minutes"].replace(" min", "", regex=True))

# %%
movies_temp["Released_Year"] = pd.to_numeric(movies_temp["Released_Year"], errors='coerce', downcast='integer')
movies_temp.dropna(inplace=True)
movies_temp["Released_Year"] = movies_temp["Released_Year"].astype(int)
movies_clean = movies_temp
movies_clean.head()
# Out:
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/3868932820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_temp["Released_Year"] = pd.to_numeric(movies_temp["Released_Year"], errors='coerce', downcast='integer')
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/3868932820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_temp.dropna(inplace=True)
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/3868932820.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_temp["Released_Year"] = movies_temp["Released_Year"].astype(int)
#    Movie_ID               Movie_Title  Released_Year Certificate  \
# 0         1  The Shawshank Redemption           1994           A
# 1         2             The Godfather           1972           A
# 2         3           The Dark Knight           2008          UA
# 3         4    The Godfather: Part II           1974           A
# 4         5              12 Angry Men           1957           U
#
#    Runtime_Minutes                 Genre              Director
# 0              142                 Drama        Frank Darabont
# 1              175          Crime, Drama  Francis Ford Coppola
# 2              152  Action, Crime, Drama     Christopher Nolan
# 3              202          Crime, Drama  Francis Ford Coppola
# 4               96          Crime, Drama          Sidney Lumet

# %% [markdown]
# Let's make the Movie_Ratings dataframe here:

# %%
movie_ratings_temp = imdb_data[["Movie_ID", "IMDB_Rating", "Meta_score", "No_of_Votes"]]
movie_ratings_temp.dropna(inplace=True)
movie_ratings_temp.head()
# Out:
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/2238758908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_ratings_temp.dropna(inplace=True)
#    Movie_ID  IMDB_Rating  Meta_score  No_of_Votes
# 0         1          9.3        80.0      2343110
# 1         2          9.2       100.0      1620367
# 2         3          9.0        84.0      2303232
# 3         4          9.0        90.0      1129952
# 4         5          9.0        96.0       689845

# %%
# We'll do some similar light processing here:
movie_ratings_temp = movie_ratings_temp.rename(columns={'Meta_score':'Metacritic_Score', 'No_of_Votes':'No_of_IMDB_Votes'})
movie_ratings_temp.insert(0, 'Rating_ID', movie_ratings_temp.index + 1)
movie_ratings_temp['Metacritic_Score'] = movie_ratings_temp['Metacritic_Score'].astype(int)
movie_ratings_clean = movie_ratings_temp

# %% [markdown]
# We now have our processed data for Movies and Movie_Ratings. Let's process our Movie_Box_Office data.

# %%
movie_box_office_temp = imdb_data[["Movie_ID", "Gross"]]
movie_box_office_temp.rename({'Gross':'Gross_USD'})
movie_box_office_temp.insert(0, 'Movie_Box_Office_ID', movie_box_office_temp.index + 1)
movie_box_office_temp['Gross'].replace(",", "", regex=True, inplace=True)
movie_box_office_temp.dropna(inplace=True)
movie_box_office_temp['Gross'] = movie_box_office_temp['Gross'].astype(int)
movie_box_office_clean = movie_box_office_temp
# Out:
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/353731734.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_box_office_temp['Gross'].replace(",", "", regex=True, inplace=True)
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/353731734.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_box_office_temp.dropna(inplace=True)
# /var/folders/0d/zlx05bv95f3d2btffmx_j44c0000gp/T/ipykernel_74904/353731734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_box_office_temp['Gross'] = movie_box_office_temp['Gross'].astype(int)

# %% [markdown]
# Lastly, let's get our Oscar_Nominations data. This comes from a different file that we ingested into our oscar_data DataFrame.

# %%
to_drop = [
    "year_ceremony",
    "ceremony",
    "name"
]

oscar_data.drop(to_drop, inplace=True, axis=1)

# %%
oscar_data.head(50)
# Out:
#     year_film                      category                     name  \
# 0        1927                         ACTOR      Richard Barthelmess
# 1        1927                         ACTOR            Emil Jannings
# 2        1927                       ACTRESS           Louise Dresser
# 3        1927                       ACTRESS             Janet Gaynor
# 4        1927                       ACTRESS           Gloria Swanson
# 5        1927                 ART DIRECTION            Rochus Gliese
# 6        1927                 ART DIRECTION  William Cameron Menzies
# 7        1927                 ART DIRECTION             Harry Oliver
# 8        1927                CINEMATOGRAPHY            George Barnes
# 9        1927                CINEMATOGRAPHY           Charles Rosher
# 10       1927                CINEMATOGRAPHY              Karl Struss
# 11       1927    DIRECTING (Comedy Picture)          Lewis Milestone
# 12       1927    DIRECTING (Comedy Picture)                Ted Wilde
# 13       1927  DIRECTING (Dramatic Picture)            Frank Borzage
# 14       1927  DIRECTING (Dramatic Picture)           Herbert Brenon
# 15       1927  DIRECTING (Dramatic Picture)               King Vidor
# 16       1927           ENGINEERING EFFECTS           Ralph Hammeras
# 17       1927           ENGINEERING EFFECTS              Roy Pomeroy
# 18       1927           ENGINEERING EFFECTS         Nugent Slaughter
# 19       1927           OUTSTANDING PICTURE        The Caddo Company
# 20       1927           OUTSTANDING PICTURE                      Fox
# 21       1927           OUTSTANDING PICTURE   Paramount Famous Lasky
# 22       1927   UNIQUE AND ARTISTIC PICTURE                      Fox
# 23       1927   UNIQUE AND ARTISTIC PICTURE      Metro-Goldwyn-Mayer
# 24       1927   UNIQUE AND ARTISTIC PICTURE   Paramount Famous Lasky
# 25       1927          WRITING (Adaptation)              Alfred Cohn
# 26       1927          WRITING (Adaptation)         Anthony Coldeway
# 27       1927          WRITING (Adaptation)          Benjamin Glazer
# 28       1927      WRITING (Original Story)               Lajos Biro
# 29       1927      WRITING (Original Story)                Ben Hecht
# 30       1927       WRITING (Title Writing)             Gerald Duffy
# 31       1927       WRITING (Title Writing)           Joseph Farnham
# 32       1927       WRITING (Title Writing)       George Marion, Jr.
# 33       1927                 SPECIAL AWARD             Warner Bros.
# 34       1927                 SPECIAL AWARD          Charles Chaplin
# 35       1928                         ACTOR          George Bancroft
# 36       1928                         ACTOR            Warner Baxter
# 37       1928                         ACTOR           Chester Morris
# 38       1928                         ACTOR                Paul Muni
# 39       1928                         ACTOR              Lewis Stone
# 40       1928                       ACTRESS          Ruth Chatterton
# 41       1928                       ACTRESS            Betty Compson
# 42       1928                       ACTRESS            Jeanne Eagels
# 43       1928                       ACTRESS         Corinne Griffith
# 44       1928                       ACTRESS              Bessie Love
# 45       1928                       ACTRESS            Mary Pickford
# 46       1928                 ART DIRECTION              Hans Dreier
# 47       1928                 ART DIRECTION           Cedric Gibbons
# 48       1928                 ART DIRECTION          Mitchell Leisen
# 49       1928                 ART DIRECTION  William Cameron Menzies
#
#                                  film  winner
# 0                           The Noose   False
# 1                    The Last Command    True
# 2                     A Ship Comes In   False
# 3                          7th Heaven    True
# 4                      Sadie Thompson   False
# 5                             Sunrise   False
# 6                           The Dove;    True
# 7                          7th Heaven   False
# 8                   The Devil Dancer;   False
# 9                             Sunrise    True
# 10                            Sunrise    True
# 11                Two Arabian Knights    True
# 12                             Speedy   False
# 13                         7th Heaven    True
# 14                    Sorrell and Son   False
# 15                          The Crowd   False
# 16                                NaN   False
# 17                              Wings    True
# 18                                NaN   False
# 19                         The Racket   False
# 20                         7th Heaven   False
# 21                              Wings    True
# 22                            Sunrise    True
# 23                          The Crowd   False
# 24                              Chang   False
# 25                    The Jazz Singer   False
# 26                     Glorious Betsy   False
# 27                         7th Heaven    True
# 28                   The Last Command   False
# 29                         Underworld    True
# 30  The Private Life of Helen of Troy   False
# 31                                NaN    True
# 32                                NaN   False
# 33                                NaN    True
# 34                                NaN    True
# 35                        Thunderbolt   False
# 36                     In Old Arizona    True
# 37                              Alibi   False
# 38                        The Valiant   False
# 39                        The Patriot   False
# 40                           Madame X   False
# 41                         The Barker   False
# 42                         The Letter   False
# 43                    The Divine Lady   False
# 44                The Broadway Melody   False
# 45                           Coquette    True
# 46                        The Patriot   False
# 47         The Bridge of San Luis Rey    True
# 48                           Dynamite   False
# 49                             Alibi;   False

# %%
oscar_data.rename(columns={'category':'Category', 'winner': 'Won_Oscar', 'film':'Movie_Title', 'year_film':'Released_Year'}, inplace=True)

# %%
oscar_data.dropna(inplace=True)

# %% [markdown]
# Now we need to get the movie_ids from our movie dataframe. We can do this by joining on the movie title and film columns.

# %%
oscar_data = oscar_data.merge(movies_clean, on=['Movie_Title', 'Released_Year'])

# %%
oscar_data.dropna(inplace=True)
oscar_data.head()
# Out:
#    Released_Year   Category         Director                   Movie_Title  \
# 0           1934  DIRECTING      Frank Capra         It Happened One Night
# 1           1939  DIRECTING   Victor Fleming            Gone with the Wind
# 2           1939  DIRECTING      Frank Capra  Mr. Smith Goes to Washington
# 3           1939  DIRECTING        John Ford                    Stagecoach
# 4           1940      ACTOR  Charles Chaplin            The Great Dictator
#
#    Won_Oscar  Movie_ID Certificate  Runtime_Minutes                      Genre
# 0       True       317    Approved              105            Comedy, Romance
# 1       True       315           U              238    Drama, History, Romance
# 2      False       314      Passed              129              Comedy, Drama
# 3      False       714      Passed               96  Adventure, Drama, Western
# 4      False        84      Passed              125         Comedy, Drama, War

# %% [markdown]
# Now let's do our data processing (dropping the unneeded columns, adding in our unique id column, etc)

# %%
to_drop = [
    'Movie_Title',
    'Released_Year',
    'Director',
    'Certificate',
    'Runtime_Minutes',
    'Genre'
]

oscar_nominations_temp = oscar_data.drop(to_drop, axis=1)

# %%
oscar_nominations_temp.insert(0, 'Oscar_Nomination_ID', oscar_data.index + 1)
oscar_nominations_clean = oscar_nominations_temp

# %% [markdown]
# We finally have all the data we need. Here are the final dataframes for each of our 4 tables.

# %%
movies_clean
# Out:
#      Movie_ID               Movie_Title  Released_Year Certificate  \
# 0           1  The Shawshank Redemption           1994           A
# 1           2             The Godfather           1972           A
# 2           3           The Dark Knight           2008          UA
# 3           4    The Godfather: Part II           1974           A
# 4           5              12 Angry Men           1957           U
# ..        ...                       ...            ...         ...
# 993       994                    Blowup           1966           A
# 994       995        A Hard Day's Night           1964           U
# 995       996    Breakfast at Tiffany's           1961           A
# 996       997                     Giant           1956           G
# 997       998     From Here to Eternity           1953      Passed
#
#      Runtime_Minutes                     Genre                Director
# 0                142                     Drama          Frank Darabont
# 1                175              Crime, Drama    Francis Ford Coppola
# 2                152      Action, Crime, Drama       Christopher Nolan
# 3                202              Crime, Drama    Francis Ford Coppola
# 4                 96              Crime, Drama            Sidney Lumet
# ..               ...                       ...                     ...
# 993              111  Drama, Mystery, Thriller  Michelangelo Antonioni
# 994               87    Comedy, Music, Musical          Richard Lester
# 995              115    Comedy, Drama, Romance           Blake Edwards
# 996              201            Drama, Western          George Stevens
# 997              118       Drama, Romance, War          Fred Zinnemann
#
# [898 rows x 7 columns]

# %%
movie_ratings_clean
# Out:
#      Rating_ID  Movie_ID  IMDB_Rating  Metacritic_Score  No_of_IMDB_Votes
# 0            1         1          9.3                80           2343110
# 1            2         2          9.2               100           1620367
# 2            3         3          9.0                84           2303232
# 3            4         4          9.0                90           1129952
# 4            5         5          9.0                96            689845
# ..         ...       ...          ...               ...               ...
# 995        996       996          7.6                76            166544
# 996        997       997          7.6                84             34075
# 997        998       998          7.6                85             43374
# 998        999       999          7.6                78             26471
# 999       1000      1000          7.6                93             51853
#
# [843 rows x 5 columns]

# %%
movie_box_office_clean
# Out:
#      Movie_Box_Office_ID  Movie_ID      Gross
# 0                      1         1   28341469
# 1                      2         2  134966411
# 2                      3         3  534858444
# 3                      4         4   57300000
# 4                      5         5    4360000
# ..                   ...       ...        ...
# 990                  991       991     696690
# 991                  992       992    1378435
# 992                  993       993  141843612
# 994                  995       995   13780024
# 997                  998       998   30500000
#
# [831 rows x 3 columns]

# %%
oscar_nominations_clean
# Out:
#      Oscar_Nomination_ID        Category  Won_Oscar  Movie_ID
# 0                      1       DIRECTING       True       317
# 1                      2       DIRECTING       True       315
# 2                      3       DIRECTING      False       314
# 3                      4       DIRECTING      False       714
# 4                      5           ACTOR      False        84
# ..                   ...             ...        ...       ...
# 202                  203  CINEMATOGRAPHY       True       721
# 203                  204       DIRECTING       True       721
# 204                  205       DIRECTING      False       485
# 205                  206       DIRECTING      False        34
# 206                  207       DIRECTING      False        85
#
# [207 rows x 4 columns]

# %% [markdown]
# ## Creating the Tables

# %% [markdown]
# The next step is to create the tables in Postgres with compatible schema details.

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS movies (movie_id int, title varchar,\
    released_year int, certificate varchar, runtime_minutes int, genre varchar);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS movie_ratings (rating_id int, movie_id int,\
    IMDB_rating numeric, metacritic_score int, no_of_IMDB_votes int);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS movie_box_office (box_office_id int, movie_id int,\
    gross int);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS oscar_nominations (oscar_nomination_id int, movie_id int,\
    category varchar, won_oscar boolean);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
cur.execute("SELECT tablename FROM pg_catalog.pg_tables WHERE schemaname = 'public';")
cur.fetchall()
# Out:
# [('movies',),
#  ('movie_ratings',),
#  ('movie_box_office',),
#  ('oscar_nominations',)]

# %% [markdown]
# ## Ingesting the Data

# %% [markdown]
# We will use sqlalchemy to insert a Pandas dataframe into Postgres.

# %%
# !pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in /Users/Christopher.J.Lu/anaconda3/lib/python3.11/site-packages (1.4.39)

# %%
from sqlalchemy import create_engine

# %%
conn_string = 'postgresql://Christopher.J.Lu:Housepen67!@127.0.0.1/postgres'
  
db = create_engine(conn_string) 
sql_conn = db.connect()

# %%
movies_clean.to_sql('movies', con=sql_conn, if_exists='replace', 
          index=False)
# Out:
# 898

# %%
movie_ratings_clean.to_sql('movie_ratings', con=sql_conn, if_exists='replace', index=False)
# Out:
# 843

# %%
movie_box_office_clean.to_sql('movie_box_office', con=sql_conn, if_exists='replace', index=False)
# Out:
# 831

# %%
oscar_nominations_clean.to_sql('oscar_nominations', con=sql_conn, if_exists='replace', index=False)
# Out:
# 207

# %%
cur.execute("SELECT * FROM movies LIMIT 10;")
cur.fetchall()
# Out:
# [(1, 'The Shawshank Redemption', 1994, 'A', 142, 'Drama', 'Frank Darabont'),
#  (2, 'The Godfather', 1972, 'A', 175, 'Crime, Drama', 'Francis Ford Coppola'),
#  (3,
#   'The Dark Knight',
#   2008,
#   'UA',
#   152,
#   'Action, Crime, Drama',
#   'Christopher Nolan'),
#  (4,
#   'The Godfather: Part II',
#   1974,
#   'A',
#   202,
#   'Crime, Drama',
#   'Francis Ford Coppola'),
#  (5, '12 Angry Men', 1957, 'U', 96, 'Crime, Drama', 'Sidney Lumet'),
#  (6,
#   'The Lord of the Rings: The Return of the King',
#   2003,
#   'U',
#   201,
#   'Action, Adventure, Drama',
#   'Peter Jackson'),
#  (7, 'Pulp Fiction', 1994, 'A', 154, 'Crime, Drama', 'Quentin Tarantino'),
#  (8,
#   "Schindler's List",
#   1993,
#   'A',
#   195,
#   'Biography, Drama, History',
#   'Steven Spielberg'),
#  (9,
#   'Inception',
#   2010,
#   'UA',
#   148,
#   'Action, Adventure, Sci-Fi',
#   'Christopher Nolan'),
#  (10, 'Fight Club', 1999, 'A', 139, 'Drama', 'David Fincher')]

# %%
cur.execute("SELECT * FROM movie_ratings LIMIT 10;")
cur.fetchall()
# Out:
# [(1, 1, 9.3, 80, 2343110),
#  (2, 2, 9.2, 100, 1620367),
#  (3, 3, 9.0, 84, 2303232),
#  (4, 4, 9.0, 90, 1129952),
#  (5, 5, 9.0, 96, 689845),
#  (6, 6, 8.9, 94, 1642758),
#  (7, 7, 8.9, 94, 1826188),
#  (8, 8, 8.9, 94, 1213505),
#  (9, 9, 8.8, 74, 2067042),
#  (10, 10, 8.8, 66, 1854740)]

# %%
cur.execute("SELECT * FROM movie_box_office LIMIT 10;")
cur.fetchall()
# Out:
# [(1, 1, 28341469),
#  (2, 2, 134966411),
#  (3, 3, 534858444),
#  (4, 4, 57300000),
#  (5, 5, 4360000),
#  (6, 6, 377845905),
#  (7, 7, 107928762),
#  (8, 8, 96898818),
#  (9, 9, 292576195),
#  (10, 10, 37030102)]

# %%
cur.execute("SELECT * FROM oscar_nominations LIMIT 100;")
cur.fetchall()
# Out:
# [(1, 'DIRECTING', True, 317),
#  (2, 'DIRECTING', True, 315),
#  (3, 'DIRECTING', False, 314),
#  (4, 'DIRECTING', False, 714),
#  (5, 'ACTOR', False, 84),
#  (6, 'WRITING (Original Screenplay)', False, 84),
#  (7, 'DIRECTING', True, 458),
#  (8, 'DIRECTING', False, 313),
#  (9, 'ACTOR', False, 125),
#  (10, 'DIRECTING', False, 125),
#  (11, 'DIRECTING', False, 124),
#  (12, 'DIRECTING', False, 454),
#  (13, 'DIRECTING', True, 562),
#  (14, 'DIRECTING', True, 455),
#  (15, 'DIRECTING', False, 33),
#  (16, 'DIRECTING', True, 192),
#  (17, 'WRITING (Screenplay)', True, 192),
#  (18, 'DIRECTING', False, 83),
#  (19, 'DIRECTING', False, 874),
#  (20, 'DIRECTING', False, 448),
#  (21, 'DIRECTING', False, 556),
#  (22, 'DIRECTING', True, 872),
#  (23, 'DIRECTING', True, 998),
#  (24, 'DIRECTING', True, 306),
#  (25, 'DIRECTING', False, 82),
#  (26, 'DIRECTING', False, 871),
#  (27, 'DIRECTING', False, 555),
#  (28, 'DIRECTING', True, 997),
#  (29, 'DIRECTING', True, 305),
#  (30, 'DIRECTING', False, 5),
#  (31, 'DIRECTING', False, 80),
#  (32, 'DIRECTING', False, 440),
#  (33, 'DIRECTING', True, 301),
#  (34, 'DIRECTING', False, 184),
#  (35, 'DIRECTING', True, 118),
#  (36, 'DIRECTING', False, 50),
#  (37, 'DIRECTING', False, 435),
#  (38, 'DIRECTING', False, 183),
#  (39, 'DIRECTING', True, 117),
#  (40, 'DIRECTING', False, 181),
#  (41, 'DIRECTING', False, 79),
#  (42, 'DIRECTING', False, 705),
#  (43, 'DIRECTING', True, 704),
#  (44, 'DIRECTING', False, 431),
#  (45, 'DIRECTING', True, 430),
#  (46, 'DIRECTING', True, 859),
#  (47, 'DIRECTING', False, 429),
#  (48, 'DIRECTING', False, 703),
#  (49, 'DIRECTING', True, 428),
#  (50, 'DIRECTING', False, 547),
#  (51, 'DIRECTING', False, 546),
#  (52, 'DIRECTING', False, 115),
#  (53, 'SPECIAL VISUAL EFFECTS', True, 115),
#  (54,
#   'WRITING (Screenplay--based on material from another medium)',
#   False,
#   426),
#  (55, 'DIRECTING', False, 425),
#  (56, 'DIRECTING', True, 700),
#  (57, 'DIRECTING', True, 543),
#  (58, 'DIRECTING', False, 114),
#  (59,
#   'WRITING (Screenplay--based on material from another medium)',
#   False,
#   114),
#  (60, 'DIRECTING', False, 423),
#  (61, 'DIRECTING', True, 853),
#  (62, 'DIRECTING', False, 422),
#  (63, 'DIRECTING', True, 698),
#  (64, 'DIRECTING', False, 852),
#  (65, 'DIRECTING', False, 2),
#  (66, 'DIRECTING', False, 421),
#  (67, 'DIRECTING', False, 420),
#  (68, 'DIRECTING', True, 113),
#  (69, 'DIRECTING', False, 284),
#  (70, 'WRITING (Original Screenplay)', False, 694),
#  (71, 'DIRECTING', False, 282),
#  (72, 'WRITING (Screenplay Adapted from Other Material)', False, 282),
#  (73, 'DIRECTING', False, 417),
#  (74, 'DIRECTING', False, 537),
#  (75, 'DIRECTING', False, 281),
#  (76, 'DIRECTING', True, 280),
#  (77, 'ACTOR IN A LEADING ROLE', False, 415),
#  (78, 'DIRECTING', True, 415),
#  (79, 'DIRECTING', False, 989),
#  (80, 'DIRECTING', False, 30),
#  (81,
#   'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
#   False,
#   30),
#  (82, 'DIRECTING', True, 279),
#  (83, 'DIRECTING', False, 988),
#  (84, 'DIRECTING', False, 535),
#  (85, 'DIRECTING', True, 690),
#  (86, 'WRITING (Screenplay Based on Material from Another Medium)', True, 690),
#  (87, 'DIRECTING', False, 277),
#  (88, 'DIRECTING', True, 842),
#  (89, 'DIRECTING', False, 174),
#  (90, 'DIRECTING', False, 982),
#  (91, 'DIRECTING', False, 73),
#  (92, 'DIRECTING', True, 412),
#  (93, 'DIRECTING', False, 839),
#  (94, 'DIRECTING', True, 108),
#  (95, 'DIRECTING', False, 685),
#  (96, 'DIRECTING', False, 173),
#  (97, 'WRITING (Screenplay Written Directly for the Screen)', False, 836),
#  (98, 'DIRECTING', False, 835),
#  (99, 'DIRECTING', False, 529),
#  (100, 'WRITING (Screenplay Written Directly for the Screen)', True, 529)]
